# %%
import pandas as pd
import numpy as np
df = pd.read_csv("games.csv", sep =',', header = 0, low_memory=False)

# %%
df.head(60)
# Out:
#                     Event               Site        Date Round  \
# 0            Dubai op 8th              Dubai  2006.04.26     4
# 1            Dubai op 8th              Dubai  2006.04.28     6
# 2            Dubai op 8th              Dubai  2006.04.30     8
# 3          Arab-chT Clubs              Amman  2006.05.??     2
# 4          Arab-chT Clubs              Amman  2006.05.??     5
# 5           Asia-ch Youth             Tehran  2006.06.26     4
# 6           Asia-ch Youth             Tehran  2006.06.28     7
# 7           Asia-ch Youth             Tehran  2006.06.29     8
# 8       Abu Dhabi op 16th          Abu Dhabi  2006.08.13     2
# 9       Abu Dhabi op 16th          Abu Dhabi  2006.08.15     4
# 10      Abu Dhabi op 16th          Abu Dhabi  2006.08.18     6
# 11      Abu Dhabi op 16th          Abu Dhabi  2006.08.20     8
# 12                Wch U12            Belfort  2005.07.25     7
# 13                Wch U12            Belfort  2005.07.26     9
# ...

# %%
df.count()
# Out:
# Event       282351
# Site        282351
# Date        282351
# Round       282351
# White       282351
# Black       282351
# Result      282351
# WhiteElo    282351
# BlackElo    282351
# ECO         281362
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282351 entries, 0 to 282350
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Event     282351 non-null  object
#  1   Site      282351 non-null  object
#  2   Date      282351 non-null  object
#  3   Round     282351 non-null  object
#  4   White     282351 non-null  object
#  5   Black     282351 non-null  object
#  6   Result    282351 non-null  object
#  7   WhiteElo  282351 non-null  int64
#  8   BlackElo  282351 non-null  object
#  9   ECO       281362 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 21.5+ MB

# %%
df[df.isnull().any(axis=1)]
# Out:
#                             Event          Site        Date Round  \
# 154         FIDE World Rapid 2014     Dubai UAE  2014.06.16  2.51
# 155         FIDE World Rapid 2014     Dubai UAE  2014.06.16  4.47
# 162         FIDE World Blitz 2014     Dubai UAE  2014.06.19  3.52
# 511       55th Biel GM Blitz 2022      Biel SUI  2022.07.17   3.1
# 575           9th Aeroflot Open A    Moscow RUS  2010.02.17     9
# ...                           ...           ...         ...   ...
# 279320                ch-UKR 2015      Lviv UKR  2015.12.11   8.6
# 280013      FIDE World Rapid 2014     Dubai UAE  2014.06.16  1.55
# 280156     TCh-ESP Div Honor 2017   Linares ESP  2017.08.15   2.4
# 281717                   Bern Cup          Bern  1996.??.??     1
# 282258  51st Capablanca Mem Elite  Varadero CUB  2016.06.18   9.3
#
#                           White                       Black   Result  \
# 154             Salem, AR Saleh  Breckenridge, Steven James      1-0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 989
